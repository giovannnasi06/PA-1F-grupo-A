# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannnasi06/PA-1F-grupo-A/blob/main/Aula_PA_28_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá Mundo!")
print("Olá Mundo!")
print("Olá Mundo!")
print("Olá Mundo!")
print("Olá Mundo!")
print("Olá Mundo!")
print("Olá Mundo!")

# %%
for i in range(7):
  print("Olá Mundo!")
# Out:
# Olá Mundo
# Olá Mundo
# Olá Mundo
# Olá Mundo
# Olá Mundo
# Olá Mundo
# Olá Mundo

# %%
for i in range(7):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
palavra = "python"

for i in (palavra):
  print(palavra)
# Out:
# python
# python
# python
# python
# python
# python

# %%
palavra = "python"
invertida = ""

for i in (palavra):

  invertida = i + invertida
  print (invertida)
# Out:
# p
# yp
# typ
# htyp
# ohtyp
# nohtyp

# %%
#Escrever um programa que o usuário digita uma palavra e programa verfica se a palavra é palindroma e imprime a palavra.

palavra = "asa"
invertida = ""

for i in (palavra):

  invertida = i + invertida
print(invertida)
# Out:
# asa

# %%
palavra = input("Digite uma palavra: ")
palavra_minuscula = palavra.lower()
palavra_invertida = palavra_minuscula[::-1]

if palavra_minuscula == palavra_invertida:
  print(f"A palavra '{palavra}' é um palíndromo.")
else:
  print(f"A palavra '{palavra}' NÃO é um palíndromo.")
# Out:
# Digite uma palavra: pera
# A palavra 'pera' NÃO é um palíndromo.
