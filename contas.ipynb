# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannnasi06/PA-1F-grupo-A/blob/main/contas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular a área do retangulo

# %%
# a entrada
comprimento = float(input("Digite o comprimento do retangulo:" ))
altura = float(input("Digite a altura do retangulo:" ))

# processamento
area = comprimento * altura

# saida
print= (f"O total da área do retangulo é: {area}")
# Out:
# Digite o comprimento do retangulo:8
# Digite a altura do retangulo:4

# %% [markdown]
# Fazer um cadastro de um usuário
#
# Objetivo trabalhar com string (str)
#
# Entrada de dados: Nome e idade Processamento: armazenar os dados Saida: mostrar uma mensagem de olá e a ideade do usuário

# %%
# Entrada

nome = str (input("Digite seu nome:"))
idade = int (input("Digite sua idade"))

# Processamento

print= (f"Olá {nome}, seja bem vinda!")
print= (f"Você tem {idade} anos.")
# Out:
# Digite seu nome:giovanna
# Digite sua idade15

# %% [markdown]
# Fazer um programa que calcula o dobro de um número.
#
# Entrada: um número
#
# Processamento: Calcular o dobro
#
# Saída: mostrar o resultado

# %%
#Entrada

numero = float (input("Digite um numero: "))

#Processamento

total = numero * 2

#Saida

str (f" o dobro do numero {numero} é igual a {total}")

# %% [markdown]
# Escrever um programa que caclcula a medida das notas do aluno.
# Entrada: nome, idade e as 04 notas do bimestre
# Processamento: calcular a media
# Saída: mostrar o nome do aluno e a média obtida.

# %%
 # Entrada

nome = str (input("Digite o nome do aluno:"))
idade = int (input("Digite a idade do aluno:"))
nota1 = float (input("Digite a primeira nota"))
nota2 = float (input("Digite a segunda nota"))
nota3 = float (input("Digite a terceira nota"))
nota4 = float (input("Digite a quarta nota"))

# Processsamento

media = (nota1 + nota2 + nota3 + nota4) /4

# Saída

print (f"a media da aluna {nome}, com {idade} anos é {media}")
# Out:
# Digite o nome do aluno:eva
# Digite a idade do aluno:15
# Digite a primeira nota10
# Digite a segunda nota10
# Digite a terceira nota10
# Digite a quarta nota10
# a media da aluna eva, com 15 anos é 10.0
